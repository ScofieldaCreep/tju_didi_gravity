# %%
import pandas as pd
import numpy as np
import geopandas

# %%
import pymysql
con = pymysql.connect(user='root', passwd='zhangchi', db="didi_flow", host='127.0.0.1', local_infile=1)

# %%
cur = con.cursor()
cur.execute("set names utf8")
cur.execute("set character_set_connection=utf8;")
# Out:
# 0

# %%
with open ('/Users/chizhang/Desktop/didi/deepgravity/data/didi_cd/pure_flow.csv', 'r', encoding='utf8') as f:
    reader = f.readline()
    print(reader)
    devide = reader.split(',')
    devide[-1] = devide[-1].rstrip('\n')
    print(devide)
# Out:
# id,match_end,match_start
#
# ['id', 'match_end', 'match_start']

# %%
column = ''
for dd in devide:
    column = column + dd + ' varchar(255),'

# %%
col = column.rstrip(',')

# %%
table_name = 'pure_flow'
create_table_sql = 'create table if not exists {} ({}) DEFAULT CHARSET=utf8'\
    .format(table_name, col)
cur.execute(create_table_sql)
# Out:
# 0

# %%
file_path = "/Users/chizhang/Desktop/didi/deepgravity/data/didi_cd/pure_flow.csv"
data = "load data local infile '{}' replace into table {} character set utf8 fields terminated by ',' enclosed by '\"' lines terminated by '\n' ignore 1 lines".format(file_path, table_name)
cur.execute(data.encode('utf8'))
# Out:
# 6485216

# %%
con.commit()

# %%
cur.close()

# %%
con.close()
