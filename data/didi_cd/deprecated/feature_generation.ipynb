# %%
import geopandas
import pandas as pd

# %%
oas = geopandas.read_file('output_areas.shp')

# %%
oas
# Out:
#      oa_id  Join_Count   pop  pop_den   road_den  SUM_Shape_  inter_den  sum  \
# 0        0          17  3488     5023   8.500442         1.0      24.48    2
# 1        1           4   536      772   3.726961         1.0       5.76    2
# 2        2           8  1024     1475   6.506793         1.0      11.52    7
# 3        3          24  1486     2140  16.507081         1.0      34.56  184
# 4        4           3  2319     3339   5.091071         1.0       4.32    5
# ..     ...         ...   ...      ...        ...         ...        ...  ...
# 746    746          22   602      867   9.124699         1.0      31.68   13
# 747    747          21  6537     9413   8.847477         1.0      30.24   18
# 748    748          20   569      819   7.061171         1.0      28.80   15
# 749    749          15  2730     3931   7.732232         1.0      21.60   34
# 750    750          25   771     1110  17.679137         1.0      36.00    3
#
# ...

# %%
oas.columns
# Out:
# Index(['oa_id', 'Join_Count', 'pop', 'pop_den', 'road_den', 'SUM_Shape_',
#        'inter_den', 'sum', 'H', 'poi_den', 'Shape_Leng', 'Shape_Area',
#        'Predicted', 'ln_popden', 'price_k', 'geometry'],
#       dtype='object')

# %%
oas = oas.rename(columns={"oa_id":"GEOID"})

# %%
oas
# Out:
#      GEOID  Join_Count   pop  pop_den   road_den  SUM_Shape_  inter_den  sum  \
# 0        0          17  3488     5023   8.500442         1.0      24.48    2
# 1        1           4   536      772   3.726961         1.0       5.76    2
# 2        2           8  1024     1475   6.506793         1.0      11.52    7
# 3        3          24  1486     2140  16.507081         1.0      34.56  184
# 4        4           3  2319     3339   5.091071         1.0       4.32    5
# ..     ...         ...   ...      ...        ...         ...        ...  ...
# 746    746          22   602      867   9.124699         1.0      31.68   13
# 747    747          21  6537     9413   8.847477         1.0      30.24   18
# 748    748          20   569      819   7.061171         1.0      28.80   15
# 749    749          15  2730     3931   7.732232         1.0      21.60   34
# 750    750          25   771     1110  17.679137         1.0      36.00    3
#
# ...

# %%
oas2 = geopandas.read_file('output_areas.shp')

# %%
oas2
# Out:
#      GEOID  Join_Count   pop  pop_den   road_den  SUM_Shape_  inter_den  sum  \
# 0        0          17  3488     5023   8.500442         1.0      24.48    2
# 1        1           4   536      772   3.726961         1.0       5.76    2
# 2        2           8  1024     1475   6.506793         1.0      11.52    7
# 3        3          24  1486     2140  16.507081         1.0      34.56  184
# 4        4           3  2319     3339   5.091071         1.0       4.32    5
# ..     ...         ...   ...      ...        ...         ...        ...  ...
# 746    746          22   602      867   9.124699         1.0      31.68   13
# 747    747          21  6537     9413   8.847477         1.0      30.24   18
# 748    748          20   569      819   7.061171         1.0      28.80   15
# 749    749          15  2730     3931   7.732232         1.0      21.60   34
# 750    750          25   771     1110  17.679137         1.0      36.00    3
#
# ...

# %%
tes = geopandas.read_file('tessellation.shp')
tes
# Out:
#       tile_ID                                           geometry
# 0           0  POLYGON ((73.49973 38.79265, 73.49973 38.96748...
# 1           1  POLYGON ((73.49973 38.96748, 73.49973 39.14187...
# 2           2  POLYGON ((73.49973 39.14187, 73.49973 39.31584...
# 3           3  POLYGON ((73.49973 39.31584, 73.49973 39.48937...
# 4           4  POLYGON ((73.72431 38.44171, 73.72431 38.61740...
# ...       ...                                                ...
# 25509   25509  POLYGON ((134.58517 47.75997, 134.58517 47.910...
# 25510   25510  POLYGON ((134.58517 47.91072, 134.58517 48.061...
# 25511   25511  POLYGON ((134.58517 48.06103, 134.58517 48.210...
# 25512   25512  POLYGON ((134.58517 48.21091, 134.58517 48.360...
# 25513   25513  POLYGON ((134.58517 48.36035, 134.58517 48.509...
#
# [25514 rows x 2 columns]

# %%
tes.columns
# Out:
# Index(['tile_ID', 'geometry'], dtype='object')

# %%
oas = geopandas.read_file('/Users/chizhang/Desktop/didi/data/didi_cd/output_areas.shp')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/_shim.pyx:83, in fiona._shim.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/Users/chizhang/Desktop/didi/data/didi_cd/output_areas.shp' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# /Users/chizhang/Desktop/didi/data/didi_cd/feature_generation.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/chizhang/Desktop/didi/data/didi_cd/feature_generation.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> oas = geopandas.read_file('/Users/chizhang/Desktop/didi/data/didi_cd/output_areas.shp')
#
# ...
